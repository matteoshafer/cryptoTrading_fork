# %%
import pandas as pd
import numpy as np
from functions import *

# %%
coin = 'BTC'

# %%
data, X, y = setup('BTC')

# %%
# Out:
#            volume      SMA_20      SMA_50  Volume_MA_20            OBV  \
# 0    15249.842114  63384.6340  65477.6480  11743.690520 -171947.807670
# 1    22838.079342  63267.4180  65593.8616  11355.519713 -156697.965555
# 2     5157.407265  63228.6780  65702.9752  10631.618515 -133859.886214
# 3     4487.487232  63019.6080  65796.3552  10949.304647 -139017.293479
# 4    10977.051786  62812.6935  65887.2514  10841.833691 -134529.806247
# ..            ...         ...         ...           ...            ...
# 432   8243.059013  65573.5735  66024.8888  11339.592079 -176279.184625
# 433   8243.059013  65573.5735  66024.8888  11339.592079 -176279.184625
# 434   8243.059013  65573.5735  66024.8888  11339.592079 -176279.184625
# 435   8243.059013  65573.5735  66024.8888  11339.592079 -176279.184625
# 436   3911.682058  64530.2495  65766.7366  11489.527737 -168036.125612
#
#       score_x      BB_Lower   BB_Middle      BB_Upper
# 0    0.000000  59195.320450  63384.6340  67573.947550
# ...
