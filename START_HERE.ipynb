# %% [markdown]
# # START HERE
#
# See Constants.py for the coin you want to analyze. Enter the crypto coin sign

# %% [markdown]
# 1. Get the Latest Price Data

# %%
import pandas as pd
import numpy as np
import CONSTANTS
from functions import *
import warnings
warnings.filterwarnings('ignore')

# %%
# %run CoinbaseMarketAnalysisGradient.ipynb

# %% [markdown]
# 2. Get Newspapers & Sentiment
#
# Note: can take over 20 minutes to run based on how many queries are in the file

# %%
cn = newspaper_sentiment_pipeline(COIN, newspaper_path=f'newspapers/{COIN}_newspapers.csv', queries_path='queries.txt')
cn
# Out:
#            time        low       high       open      close       volume  \
# 0    2025-06-17  104783.25  107792.90  106853.38  104878.18  2941.059097
# 1    2025-06-16  104982.26  109000.00  105600.21  106853.38  5952.783796
# 2    2025-06-15  104505.05  106184.13  105465.42  105599.25  1722.809452
# 3    2025-06-14  104351.72  106264.36  106114.53  105465.42  2256.484581
# 4    2025-06-13  102746.01  106233.00  105716.45  106118.70  7440.850143
# ...         ...        ...        ...        ...        ...          ...
# 3706 2015-07-24     276.43     291.52     277.23     289.12  7362.469083
# 3707 2015-07-23     276.28     279.75     277.96     277.39  5306.919575
# 3708 2015-07-22     275.01     278.54     277.33     277.89  4687.909383
# 3709 2015-07-21     276.85     281.27     279.96     277.32  4943.559434
# 3710 2015-07-20     277.37     280.00     277.98     280.00   782.883420
#
#        change  pct_change   timestamp  value  ... Unnamed: 0.3  Unnamed: 0.2  \
# 0    -1975.20   -1.848514  1970-01-01   51.0  ...          0.0           0.0
# 1     1253.17    1.186712  2025-06-16   51.0  ...          0.0           0.0
# 2      133.83    0.126895  2025-06-15   50.0  ...          0.0           0.0
# 3     -649.11   -0.611707  2025-06-14   52.0  ...          0.0           0.0
# 4      402.25    0.380499  2025-06-13   54.0  ...          0.0           0.0
# ...       ...         ...         ...    ...  ...          ...           ...
# 3706    11.89    4.288858  1970-01-01   51.0  ...          0.0           0.0
# 3707    -0.57   -0.205065  1970-01-01   51.0  ...          0.0           0.0
# 3708     0.56    0.201926  1970-01-01   51.0  ...          0.0           0.0
# 3709    -2.64   -0.942992  1970-01-01   51.0  ...          0.0           0.0
# 3710     2.02    0.726671  1970-01-01   51.0  ...          0.0           0.0
#
#       Unnamed: 0.1  Unnamed: 0  title  date  link  text  sentiment  score
# 0              0.0         0.0      -   NaT     -     -          -    0.0
# 1              0.0         0.0      -   NaT     -     -          -    0.0
# 2              0.0         0.0      -   NaT     -     -          -    0.0
# 3              0.0         0.0      -   NaT     -     -          -    0.0
# 4              0.0         0.0      -   NaT     -     -          -    0.0
# ...            ...         ...    ...   ...   ...   ...        ...    ...
# 3706           0.0         0.0      -   NaT     -     -          -    0.0
# 3707           0.0         0.0      -   NaT     -     -          -    0.0
# 3708           0.0         0.0      -   NaT     -     -          -    0.0
# 3709           0.0         0.0      -   NaT     -     -          -    0.0
# 3710           0.0         0.0      -   NaT     -     -          -    0.0
#
# [3711 rows x 39 columns]

# %% [markdown]
# 4. Get Tweets (external notebook)
