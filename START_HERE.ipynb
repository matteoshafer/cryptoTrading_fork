# %% [markdown]
# # START HERE
#
# See Constants.py for the coin you want to analyze. Enter the crypto coin sign

# %% [markdown]
# 1. Get the Latest Price Data

# %%
import pandas as pd
import numpy as np
import CONSTANTS
from functions import *
import warnings
warnings.filterwarnings('ignore')

# %%
# %run CoinbaseMarketAnalysisGradient.ipynb

# %% [markdown]
# 2. Get Newspapers & Sentiment
#
# Note: can take over 20 minutes to run based on how many queries are in the file

# %%
cn = newspaper_sentiment_pipeline(COIN, newspaper_path=f'newspapers/{COIN}_newspapers.csv')
cn
# Out:
#           time       low      high      open     close        volume   change  \
# 0   2024-05-08  60851.04  63013.05  62315.75  61169.53   7486.425968 -1146.22
# 1   2024-05-09  60601.60  63424.14  61169.53  63073.57   8360.055382  1904.04
# 2   2024-05-10  60150.00  63470.00  63073.55  60787.47  11511.129910 -2286.08
# 3   2024-05-11  60450.13  61482.00  60787.99  60814.63   2338.068108    26.64
# 4   2024-05-12  60576.05  61843.45  60814.64  61453.02   2694.975779   638.38
# ..         ...       ...       ...       ...       ...           ...      ...
# 432 2025-05-03  95765.13  96974.78  96929.81  95861.33   2077.556760 -1068.48
# 433 2025-05-04  94151.67  96312.51  95865.47  94272.55   2834.396865 -1592.92
# 434 2025-05-05  93500.01  95218.82  94272.54  94733.99   5180.158939   461.45
# 435 2025-05-06  93363.28  96916.25  94733.99  96839.17   6163.867558  2105.18
# 436 2025-05-07  96207.28  97738.05  96843.84  97061.99   4431.918646   218.15
#
#      pct_change      SMA_20      SMA_50  ...  Unnamed: 0.3  Unnamed: 0.2  \
# 0     -1.839374  65890.2210  66417.9682  ...           0.0           0.0
# 1      3.112726  66247.8435  66426.8854  ...           0.0           0.0
# 2     -3.624467  66472.6375  66371.6810  ...           0.0           0.0
# 3      0.043824  66850.1930  66373.6450  ...           0.0           0.0
# 4      1.049714  67183.0820  66410.7176  ...           0.0           0.0
# ..          ...         ...         ...  ...           ...           ...
# 432   -1.102323  72647.6545  69787.8322  ...           0.0           0.0
# 433   -1.661620  71251.6105  69155.3058  ...           0.0           0.0
# 434    0.489485  69965.3730  68533.2834  ...           0.0           0.0
# 435    2.222201  68693.1570  67843.8636  ...           0.0           0.0
# 436    0.225260  67274.8845  67142.8744  ...           0.0           0.0
#
#      Unnamed: 0.1  Unnamed: 0  title  date  link  text  sentiment  score
# 0             0.0         0.0      -   NaT     -     -          -    0.0
# 1             0.0         0.0      -   NaT     -     -          -    0.0
# 2             0.0         0.0      -   NaT     -     -          -    0.0
# 3             0.0         0.0      -   NaT     -     -          -    0.0
# 4             0.0         0.0      -   NaT     -     -          -    0.0
# ..            ...         ...    ...   ...   ...   ...        ...    ...
# 432           0.0         0.0      -   NaT     -     -          -    0.0
# 433           0.0         0.0      -   NaT     -     -          -    0.0
# 434           0.0         0.0      -   NaT     -     -          -    0.0
# 435           0.0         0.0      -   NaT     -     -          -    0.0
# 436           0.0         0.0      -   NaT     -     -          -    0.0
#
# [437 rows x 36 columns]

# %% [markdown]
# 4. Get Tweets (external notebook)
